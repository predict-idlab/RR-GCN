# %%
from rrgcn import RRGCNEmbedder
from torch_geometric.datasets import Entities
import torch
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import rdflib
import re
from tqdm import tqdm
import math

# !pip install transformers
from transformers import AutoTokenizer, AutoModelForMaskedLM

# %%
## edited entities.py from PyG that also saves node_features
import logging
import os
import os.path as osp
from collections import Counter
from typing import Callable, List, Optional

import numpy as np
import torch

from torch_geometric.data import (
    Data,
    InMemoryDataset,
    download_url,
    extract_tar,
)


class Entities(InMemoryDataset):
    url = 'https://data.dgl.ai/dataset/{}.tgz'

    def __init__(self, root: str, name: str,
                 transform: Optional[Callable] = None,
                 pre_transform: Optional[Callable] = None):
        self.name = name.lower()
        assert self.name in ['aifb', 'am', 'mutag', 'bgs']
        super().__init__(root, transform, pre_transform)
        self.data, self.slices = torch.load(self.processed_paths[0])

    @property
    def raw_dir(self) -> str:
        return osp.join(self.root, self.name, 'raw')

    @property
    def processed_dir(self) -> str:
        return osp.join(self.root, self.name, 'processed')

    @property
    def num_relations(self) -> int:
        return self.data.edge_type.max().item() + 1

    @property
    def num_classes(self) -> int:
        return self.data.train_y.max().item() + 1

    @property
    def raw_file_names(self) -> List[str]:
        return [
            f'{self.name}_stripped.nt.gz',
            'completeDataset.tsv',
            'trainingSet.tsv',
            'testSet.tsv',
        ]

    @property
    def processed_file_names(self) -> str:
        return 'data.pt'

    def download(self):
        path = download_url(self.url.format(self.name), self.root)
        extract_tar(path, self.raw_dir)
        os.unlink(path)

    def process(self):
        import gzip

        import pandas as pd
        import rdflib as rdf

        graph_file, task_file, train_file, test_file = self.raw_paths

        with hide_stdout():
            g = rdf.Graph()
            with gzip.open(graph_file, 'rb') as f:
                g.parse(file=f, format='nt')

        freq = Counter(g.predicates())

        relations = sorted(set(g.predicates()), key=lambda p: -freq.get(p, 0))
        subjects = set(g.subjects())
        objects = set(g.objects())
        nodes = list(subjects.union(objects))

        N = len(nodes)
        R = 2 * len(relations)

        relations_dict = {rel: i for i, rel in enumerate(relations)}
        nodes_dict = {node: i for i, node in enumerate(nodes)}

        edges = []
        node_features = {}
        for s, p, o in g.triples((None, None, None)):
            src, dst, rel = nodes_dict[s], nodes_dict[o], relations_dict[p]
            edges.append([src, dst, 2 * rel])
            edges.append([dst, src, 2 * rel + 1])

            # SAVE LITERAL VALUES
            if isinstance(o, rdf.Literal):
                literal_type = p#type(o.value)
                if literal_type not in node_features:
                    node_features[literal_type] = [[dst], [o.value]]
                else:
                    node_features[literal_type][0].append(dst)
                    node_features[literal_type][1].append(o.value)

        edges = torch.tensor(edges, dtype=torch.long).t().contiguous()
        perm = (N * R * edges[0] + R * edges[1] + edges[2]).argsort()
        edges = edges[:, perm]

        edge_index, edge_type = edges[:2], edges[2]

        if self.name == 'am':
            label_header = 'label_cateogory'
            nodes_header = 'proxy'
        elif self.name == 'aifb':
            label_header = 'label_affiliation'
            nodes_header = 'person'
        elif self.name == 'mutag':
            label_header = 'label_mutagenic'
            nodes_header = 'bond'
        elif self.name == 'bgs':
            label_header = 'label_lithogenesis'
            nodes_header = 'rock'

        labels_df = pd.read_csv(task_file, sep='\t')
        labels_set = set(labels_df[label_header].values.tolist())
        labels_dict = {lab: i for i, lab in enumerate(list(labels_set))}
        nodes_dict = {np.unicode(key): val for key, val in nodes_dict.items()}

        train_labels_df = pd.read_csv(train_file, sep='\t')
        train_indices, train_labels = [], []
        for nod, lab in zip(train_labels_df[nodes_header].values,
                            train_labels_df[label_header].values):
            train_indices.append(nodes_dict[nod])
            train_labels.append(labels_dict[lab])

        train_idx = torch.tensor(train_indices, dtype=torch.long)
        train_y = torch.tensor(train_labels, dtype=torch.long)

        test_labels_df = pd.read_csv(test_file, sep='\t')
        test_indices, test_labels = [], []
        for nod, lab in zip(test_labels_df[nodes_header].values,
                            test_labels_df[label_header].values):
            test_indices.append(nodes_dict[nod])
            test_labels.append(labels_dict[lab])

        test_idx = torch.tensor(test_indices, dtype=torch.long)
        test_y = torch.tensor(test_labels, dtype=torch.long)

        data = Data(edge_index=edge_index, edge_type=edge_type,
                    train_idx=train_idx, train_y=train_y, test_idx=test_idx,
                    test_y=test_y, num_nodes=N, node_features=node_features)

        torch.save(self.collate([data]), self.processed_paths[0])

    def __repr__(self) -> str:
        return f'{self.name.upper()}{self.__class__.__name__}()'


class hide_stdout(object):
    def __enter__(self):
        self.level = logging.getLogger().level
        logging.getLogger().setLevel(logging.ERROR)

    def __exit__(self, *args):
        logging.getLogger().setLevel(self.level)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
dataset = Entities('./', 'am')
data = dataset[0].to(device)

# %%
for k, v in data.node_features.items():
    print(k)
    print(v[1][0:10])
    print(f'num entries {len(v[1])} - unique entries {len(set(v[1]))}')
    print('--')
# Out:
# http://purl.org/collections/nl/am/dimensionPart
# ['passe-partout', 'geheel', 'b-maat', 'a-maat', 'c-maat', 'c-maat', 'a-maat', 'a-maat', 'KA 12834.1', 'a']
# num entries 6028 - unique entries 577
# --
# http://purl.org/collections/nl/am/reproductionReference
# ['KA_6989.JPG', 'A_10069_000.jpg', 'KA_14018.JPG', 'A_12399_000.jpg', 'O 2577.38', 'A_19506', 'O 11540.09', 'O 1320.34', 'A_50466', 'A_44633']
# num entries 110861 - unique entries 104142
# --
# http://www.w3.org/2000/01/rdf-schema#label
# ['WH 1ste verdieping 2003-01-23 2003-08-22 intern 15111 Transportnummer:2003-0066 intern ', 'CBD 3 kast 84-3 1975-01-01   17471   ', ' Portretten van Nederlandse beeldende kunstenaars : repertorium [R] p. 132 ', 'Een en ander over glasgravure p. 276, t.o. p. 276 afb. ', 'AHM dep 3 blok 2-4 1975-01-01   16378   ', 'AHM textielrestauratie 2006-10-24 2008-09-03  16283   ', 'WH Palet Willet boudoir 2001-11-04 2001-08-28  26292   ', 'AHM PK stelling 27-14 II 2009-03-21   14631 doos nr 251 intern ', ' Geschiedenis van Amsterdam dl. III, p. 454 ', 'breedte 86.5 cm    ']
# num entries 341964 - unique entries 68566
# --
# http://purl.org/collections/nl/am/name
# ['Stichting Kerkelijk Kunstbezit in Nederland', 'Maison Descartes', 'Janssen, Winfried', 'Velsen, Tadeus van', 'Mirto, Alfonso', 'Sotheby Mak van Waay, grote zaal', "Cliché's van Leer & Co", 'Linnet, Ragni', 'Landwerh, John', 'Siemensma, Ferry']
# num entries 66937 - unique entries 66937
# --
# http://purl.org/collections/nl/am/dimensionUnit
# ['cm', 'cm', 'cm', 'cm', 'cm', 'cm', 'cm', 'cm', 'cm', 'cm']
# num entries 152555 - unique entries 13
# --
# http://purl.org/collections/nl/am/currentLocationLref
# ['32216', '17313', '28887', '28928', '16415', '15376', '22153', '16644', '32226', '15127']
# num entries 137474 - unique entries 5109
# --
# http://purl.org/collections/nl/am/currentLocationType
# ['intern', 'extern', 'intern', 'intern', 'intern', 'intern', 'extern', 'intern', 'binnenkomend', 'intern']
# num entries 63542 - unique entries 22
# --
# http://purl.org/collections/nl/am/reproductionDate
# ['1998-03-16', '1997-06-05', '2009-12-01', '2009-04', '2004-10-20', '2004-03-22', '2004-10-13', '1999', '1999', '1999']
# num entries 73697 - unique entries 1269
# --
# http://purl.org/collections/nl/am/currentLocationNotes
# ['doos 5, boeknr. 81', 'doos 31, boeknr. 343', 'transportformulier 2008-0032', 'doos 11a', 'doos nr 109', 'doos nr 200', 'Transportnummer:2005-0245', 'doos 17, boeknr. 346', 'doos 33, boeknr. 321', 'doos nr 160']
# num entries 53819 - unique entries 4797
# --
# http://purl.org/collections/nl/am/objectNumber
# ['KA 13641', 'A 15826', 'KB 2122.7', 'TA 36547', 'KA 18210', 'DA 19.142', 'A 16256', 'KA 19183', 'PB 99', 'KA 18683']
# num entries 73448 - unique entries 73448
# --
# http://purl.org/collections/nl/am/priref
# ['24940', '12843', '39315', '33995', '12711', '843', '59058', '4256', '29404', '27437']
# num entries 167399 - unique entries 75094
# --
# http://purl.org/collections/nl/am/reproductionReferenceLref
# ['62510', '51562', '133951', '134204', '8884', '44329', '70500', '38746', '40582', '129574']
# num entries 114453 - unique entries 107380
# --
# http://purl.org/collections/nl/am/documentationTitle
# ['Amsterdamer Schützenbildnis: Teil 5. Katalog der frühen amsterdamer Schützenbildnissse (1529-1566)', 'glazen bekers, naar de volgorde waarin zij geplaatst zijn in de vitrine', 'Amsterdams Historisch Museum : schilderijen daterend van voor 1800 : voorlopige catalogus', 'Beschrijving der schilderijen, teekeningen, prenten, prentwerken en boeken, in het Museum Fodor, te Amsterdam', 'werk van Jan en Casper Luyken', 'Frederik Sieger', 'Andriessen-kamer in de collectie van het Amsterdams Historisch Museum', 'Amsterdam in de schilderkunst', 'Vier eeuwen Herengracht : geveltekeningen van alle huizen aan de gracht, twee historische overzichten en de beschrijving van elk pand met zijn eigenaars en bewoners', 'werk van Jan en Casper Luyken']
# num entries 38416 - unique entries 5594
# --
# http://purl.org/collections/nl/am/title
# ['Bak', 'Japonlijfje', 'Het opzetten van den tabernakel, De gouden kandelaar, De heerlykheyd des heeren, Viering van het loofhuttenfeest', 'Schutters van de compagnie van kapitein Adriaen Pietersz. Raep en Dirck Hasselaer', 'Historien Onses Tyds, Behelzende Saken Van Staat En Oorlogh, Voorgevallen in, en omtrent de Vereenigde Nederlanden, En door geheel Europa, Mitsgaders in meest alle de andere Deelen des Werelds. Beginnende met het Jaar 1669. daar het De Heer Lieuwe van Aitzema heeft gelaten; en eyndigende na het Jaar 1679. met het sluyten der Nimeegsche en Algemeene Vrede Door den Heer L. Sylvius. Verçiert met schoone Konst-plaaten', 'Schoenendoos (van Barbiepop)', 'Tekstpagina met opdracht uit "Lust-hof des gemoets"', 'Mythologische figuur musicerend', 'Namiddagjapon met sjerp', "Stempelafdruk 'Mairie de la ville d'amsterdam'"]
# num entries 75883 - unique entries 45768
# --
# http://www.w3.org/2004/02/skos/core#prefLabel
# ['diameter handvat', 'CBD 3 stelling 3-10', 'Paradiso', 'wapenaccessoire', 'demonstratie tegen kruisraketten', 'hoogte blad', 'renteboekje', 'waardepapier', 'Vesoul', 'miniaturen']
# num entries 28048 - unique entries 28048
# --
# http://purl.org/collections/nl/am/currentLocationDateStart
# ['2003-06', '1997', '1975-01-01', '1975-01-01', '2009-03-21', '2009-01-05', '2001-01-30', '1975-01-01', '1975-01-01', '1975-01-01']
# num entries 131997 - unique entries 3099
# --
# http://purl.org/collections/nl/am/dimensionValue
# ['14.5', '16.11', '4.1', '10', '37.2', '7.5', '23', '5.9', '23.06', '10.5']
# num entries 151734 - unique entries 7951
# --
# http://purl.org/collections/nl/am/documentationSortyear
# ['2008', '1996', '2002', '1995', '1928', '1881', '1845', '1876', '1914', '1968']
# num entries 36129 - unique entries 282
# --
# http://purl.org/collections/nl/am/productionDateStart
# ['1857', '1917', '1708', '1692', '1732', '1750', '1793', '1782', '1700', '1700']
# num entries 58055 - unique entries 655
# --
# http://purl.org/collections/nl/am/selected
# ['False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False']
# num entries 66966 - unique entries 1
# --
# http://purl.org/collections/nl/am/AHMTextsAuthorLref
# ['70', '15', '5', '142', '5', '47', '5', '15', '15', '30']
# num entries 4411 - unique entries 53
# --
# http://purl.org/collections/nl/am/reproductionIdentifierURL
# ['..\\..\\DAT\\collectie\\images\\PB_808.jpg', '..\\..\\DAT\\collectie\\images\\PA_324.JPG', '..\\..\\DAT\\collectie\\images\\KB_895.JPG', '..\\..\\DAT\\collectie\\images\\KA_756.JPG', '..\\..\\DAT\\collectie\\images\\KA_5543.JPG', '..\\..\\dat\\collectie\\images\\pictura2009\\S_A_16666_000.jpg', '..\\..\\DAT\\collectie\\images\\LUYKEN\\A_19305_1.JPG', '..\\..\\DAT\\collectie\\images\\KA_10360.JPG', '..\\..\\DAT\\collectie\\images\\LA_361_F.jpg', '..\\..\\DAT\\collectie\\images\\LUYKEN\\A_44835.JPG']
# num entries 68178 - unique entries 64260
# --
# http://purl.org/collections/nl/am/creatorRole
# ['goud- en zilversmid', 'beeldhouwer', 'etser', 'etser', 'uitgever', 'etser', 'goud- en zilversmid', 'goud- en zilversmid', 'auteur', 'uitgever']
# num entries 45772 - unique entries 149
# --
# http://purl.org/collections/nl/am/exhibitionDateEnd
# ['2005-03-13', '2003-01-12', '1989-04-23', '2001-01-28', '1987-01-04', '2008-11-24', '2003-01-26', '2003-08-17', '1991-01-06', '2005-01-23']
# num entries 9506 - unique entries 923
# --
# http://purl.org/collections/nl/am/productionDateEnd
# ['1968', '1812', '1664', '1801', '1849', '1703', '1855', '1817', '1899', '1598']
# num entries 55886 - unique entries 653
# --
# http://purl.org/collections/nl/am/documentationPageReference
# ['[p. 22]', 'p. 72-75 nr. 1, afb. p. 74', 'p. 36 nr 46', 'p. 98, 103, afb. 33', 'p. 199 nr. 3369', 'dl. 2 p. 29', 'p. 12 nr. 28', 'p. 233 afb. 1, p. 234 afb. 3', '[X] p. 11 nr. 106', '[R[ p. 145 nr. 880']
# num entries 38424 - unique entries 4645
# --
# http://purl.org/collections/nl/am/currentLocationDateEnd
# ['2009-03-21', '2006-01-27', '2009-03-21', '2004-05-31', '2006-10-09', '1999', '2009-03-21', '2009-03-21', '2007-05-22', '2009-03-21']
# num entries 62446 - unique entries 2180
# --
# http://purl.org/collections/nl/am/AHMTextsPubl
# ['2007-10-08', '2007-10-31', '2008-03-17', '2008-03-06', '2007-09-26', '2007-11-26', '2009-02-20', '2008-03-18', '2008-07-06', '2007-10-15']
# num entries 2275 - unique entries 84
# --
# http://purl.org/collections/nl/am/dimensionNotes
# ['incl. minimale marge', 'incl. minimale marge', 'incl. minimale marge', 'incl. minimale marge', 'incl. minimale marge', 'met 25 kralen', 'incl. minimale marge', 'incl. minimale marge', 'incl. minimale marge', 'incl. scan marge']
# num entries 28665 - unique entries 779
# --
# http://purl.org/collections/nl/am/exhibitionLref
# ['66', '6041', '5553', '4624', '4615', '4605', '5707', '5148', '466', '307']
# num entries 10617 - unique entries 1164
# --
# http://purl.org/collections/nl/am/alternativeNumberType
# ['vE/vdK prent', 'oud inv.nr', 'vE/vdK prent', 'vE/vdK prent', 'oud inv.no.', 'vE/vdK prent', 'catalogus', 'vE/vdK prent', 'vE/vdK prent', 'vE/vdK prent']
# num entries 21313 - unique entries 113
# --
# http://purl.org/collections/nl/am/documentationShelfmark
# ['O.b/Thie.', 'Q.b.alg./Alle', 'S.f.Amsterdam,AHM/tent.1994', 'R.f.2/Egge.', 'F.g/Mole.', 'Q.b.alg./Alle', 'I.b/Nieu.', 'Q.a.17e/Art', 'P.a.21E/Docu.', 'P.f/Hoop']
# num entries 29099 - unique entries 2862
# --
# http://purl.org/collections/nl/am/acquisitionDate
# ['1887-10-28', '1989', '2001-02-14', '1907', '2003-11', '1907', '1989', '1972-01-04', '1907', '1975-08-14']
# num entries 64691 - unique entries 3514
# --
# http://purl.org/collections/nl/am/documentationTitleLref
# ['11531', '4157', '27022', '16203', '200001058', '23343', '23343', '200010050', '28321', '10153']
# num entries 38605 - unique entries 5781
# --
# http://purl.org/collections/nl/am/reproductionFormat
# ['6 x 6 cm', '167 mB', '22.5 mB', 'kleinbeeld', '300 dpi/25.5 x 16.6 cm', '37.9 mB', '6 x 6 cm', '6 x 6 cm', '6 x 6 cm', '25.2 mB']
# num entries 10444 - unique entries 927
# --
# http://purl.org/collections/nl/am/dimensionPrecision
# ['ca', 'ca', 'ca', 'circa', 'circa', 'ca', 'ca', 'ca', 'ca', 'ca']
# num entries 28920 - unique entries 51
# --
# http://purl.org/collections/nl/am/AHMTextsDate
# ['1998', '2009-03', '1995', '2007-11', '1995', '2003', '1998', '2003', '1979', '2009-03']
# num entries 5130 - unique entries 128
# --
# http://purl.org/collections/nl/am/birthDateStart
# ['1770', '1803-05-01', '1697', '1814-08-14', '1717', '1591', '1837-06-24', '1769', '1702-03-25', '1821']
# num entries 5199 - unique entries 2313
# --
# http://purl.org/collections/nl/am/documentationTitleArticle
# ['The', 'The', 'De', 'De', 'Het', 'De', 'De', 'Het', 'Het', "'"]
# num entries 8797 - unique entries 38
# --
# http://purl.org/collections/nl/am/alternativeNumber
# ['3958', 'VdH 12', '4414 K', 'C 86', 'Blankert 304', '4221', '0027', 'cat. 1981 11', 'oka 4316/Z 158', 'Jumbo 722']
# num entries 21262 - unique entries 11125
# --
# http://purl.org/collections/nl/am/AHMTextsType
# ['cat. Zilver', 'cat. Zilver', 'zaaltekst', 'zaaltekst', 'zaaltekst', 'cat. Beelden', 'zaaltekst', 'cat. Tekeningen', 'cat. Kopstukken', 'webtekst']
# num entries 7981 - unique entries 30
# --
# http://purl.org/collections/nl/am/birthDateEnd
# ['1624', '1804-01-13', '1868-09-15', '1828-04-22', '1701', '1725', '1597', '1686', '1882-05-13', '1762-01-22']
# num entries 3323 - unique entries 2086
# --
# http://purl.org/collections/nl/am/exhibitionTitle
# ['De stad door de jaren : de geschiedenis van Amsterdam 1880-1998', 'Jan Eissenloeffel (1876-1957)', 'De Hollandsche schilderkunst van Jeroen Bosch tot Rembrandt', 'Toen hier... Hongerwinter en bevrijding in Amsterdam', 'Mijn hoofddoek', 'Servies in de ontvangstruimte', 'Keuze uit de collectie Fodor', 'Servies in de ontvangstruimte', 'Een huis vol bloemen : zomerse kleurenpracht in donkere jaargetijden', 'ADAM, man en mode']
# num entries 10471 - unique entries 1094
# --
# http://purl.org/collections/nl/am/alternativeNumberInstitution
# ['voorlopig', 'Backerstichting', 'Koninklijk Oudheidkundig Genootschap', 'Backerstichting', 'Stadhuisbibliotheek', 'Backerstichting', 'voorlopig', 'ICN', 'Backerstichting', 'voorlopig']
# num entries 892 - unique entries 59
# --
# http://purl.org/collections/nl/am/usedFor
# ['Vastricx, Hendrik Willemsz', "Maatschappij tot nut van 't algemeen", "d'Ailly, A.J.", 'Hooft, Corneils Pietersz.', 'Claassen-Huyer, Margaretha Carolina', 'Vrolijk, Johannes Martinus', 'Arondéus, Willem', '(Museum Fodor)', 'vrijmetselaarsloge', 'Stichting geschiedkundig medisch-pharmaceutisch museum']
# num entries 3883 - unique entries 3857
# --
# http://purl.org/collections/nl/am/birthPlace
# ['Amsterdam', 'Antwerpen', 'Naaldwijk', 'Amsterdam', 'Düsseldorf', 'Amsterdam', 'Amsterdam', 'Santpoort', 'Amsterdam', 'Hamburg']
# num entries 3065 - unique entries 741
# --
# http://purl.org/collections/nl/am/currentLocationFitness
# ['tentoonstelling , bruikleencontract : AHM98.02/2', 'tentoonstelling Suasso juwelen', 'intern', 'bruikleen uit, kort , bruikleencontract : UB00.004', 'voor restauratie en bruikleen', 'tentoonstelling Japan', 'intern', 'langdurig bruikleen', 'checken', 'langdurig bruikleen']
# num entries 4857 - unique entries 502
# --
# http://purl.org/collections/nl/am/exhibitionDateStart
# ['1982-02-05', '1990-10-23', '2008-03-01', '2005-09-23', '2009-05-17', '1999-12-04', '2007-11-29', '2008-03-01', '2008-03-01', '1996-03-07']
# num entries 10018 - unique entries 1009
# --
# http://purl.org/collections/nl/am/creatorQualifier
# ['naar', 'naar', 'kopie naar', 'naar', 'naar', 'naar', 'naar', 'naar', 'naar', 'waarschijnlijk']
# num entries 5100 - unique entries 87
# --
# http://purl.org/collections/nl/am/AHMTextsTekst
# ["in 1656 ontving Quellinus 168 gulden voor het vervaardigen van vier `wapens vanden heere commissarissen,/ door ordre der heeren ende borger Myn heer graaf ende mijn heer spigel'. Deze vermelding heeft vrijwel zeker betrekking op de vier rijk gesneden wapenborden van leden van de families Roeters, Reynst, Bas en Trip (zie ook cat. nrs. 98, 100, 101), die bij de inwijding van het nieuwe stadhuis in 1655 commissarissen waren van de Wisselbank.\nDe Wisselbank was gehuisvest in een aantal vertrekken op de begane grond in de zuidoosthoek van het 17de-eeuwse stadhuis. Vermoedelijk waren de schilden aangebracht boven de vier deuren in het kantoor van de commisarissen.", "Liefdadige instellingen bezaten in de achttiende en negentiende eeuw veelal zilverwerk ten gebruike der 'Heeren Regenten en Mevrouwen Regentessen'. Het Diaconie Oude Vrouwenhuis vormde hierop geen uitzondering. Het bestuur van het huis bestond uit een college van diakenen en diaconessen, elk met een eigen vertrek aan weerszijden van de kerkzaal (Bakker/Fleurbaay/Gerlagh 1988, p. 323 nr. 329). Over de bestelling en het gebruik van het zilver van de diaconie is weinig bekend.\nWaarschijnlijk werden losse lepels, vorken en messen en later ook wel complete couverts op kosten van een zojuist verkozen diaken of diacones besteld. De gegraveerde opschriften verwijzen naar de naam van de verkozene en het jaar waarin de verkiezing plaatsvond.\nWanneer een diaken of diacones zijn of haar bestuursfunctie beëindigde of overleed, bleef het eetgerei deel uitmaken van de inventaris van het Oude Vrouwenhuis. Twee vermeldingen in het archief van de firma As. Bonebakker & Zoon lijken deze veronderstelling te bevestigen.\nOp 10 februari 1853 bestelde J.C. la Verge Jolles '1 lepel en 1 vork kk 105 à 108 f. 11,35/ werkloon voor het graveren van inscriptie f. 3,90'. Op 24 februari 1858 kocht mej. A.H. Wendelaar bij Bonebakker een tafelcouvert, inclusief graveringen, voor een bedrag van f. 15,75 (GAA, PA 406, Deb. boek 1853, p. 40; Deb. boek 1858, p. 45) (vriendelijke mededeling van de heer B.J. van Benthem).\nDe achttiende-eeuwse personen (alleen diaconessen) zijn in eerste instantie geïdentificeerd op grond van een geschilderde naamlijst uit 1783, in 2001 aanwezig in de kerkzaal van het verpleeghuis Amstelhof. De volledige titel van deze lijst luidt: NAMEN VAN DE EERWAARDE ZUSTEREN DIACONESSEN/ VAN DE WARE gereformeerde kerke Jesu Christi TOT AMSTERDAM/ welke bij GELEGENHEID der VIERING van het EERSTE EEUWFEEST/ DER BOUW en STICHTING van het DIACONIE OUDE VROUWEN HUIS/ in den Dienst WAREN en Vervolgens zijn AANGEKOMEN ANNO 1783/ (afgekort tot: N1783). Twee Herenboekjes, berustend bij het Gemeentearchief Amsterdam, verschaften aanvullende informatie (afgekort tot: H1787, H1791).\nVoor de identificatie van de negentiende-eeuwse personen (diakenen en diaconessen) vormde het archief van de Nederlands Hervormde Gemeente (GAA, PA 377) een belangrijke bron. In het bijzonder is gebruik gemaakt van: Verdeeling van het diakende DIENSTWERK in AMSTERDAM 1842-1857, waarin: 'Namen en woonplaatsen van de Diakenen in het jaar ...' en 'Namen der in Leven zijnde en alhier woonende ouderlingen en diakenen en de Jaren hunner Verkiezing' (GAA, PA 377A/254A). Het archiefonderzoek heeft meer gegevens opgeleverd dan in bijgaande lijst kon worden opgenomen. Deze informatie is te raadplegen in het Documentatie archief van het Amsterdams Historisch Museum (met vriendelijke dank aan de heer J. Wit voor het door hem verrichtte onderzoek in genoemde archieven).\nIn 1994 kwam het complete zilverbezit van het Diaconie Oude Vrouwenhuis onder de hamer (Glerum 1994, p. 32-35 nr. 201-233). Het Amsterdams Historisch Museum kon op deze veiling slechts twee stukken verwerven (cat.nr. KA 19509, KA 19510). Het hier besproken tafelzilver werd door de Diaconie der Hervormde Gemeente aan de veiling onttrokken en alsnog aan het museum geschonken. Zie over het Diaconie Oude Vrouwenhuis het commentaar bij cat.nr. KA 19509.\nZie voor  ...
# num entries 7336 - unique entries 5188
# --
# http://purl.org/collections/nl/am/deathPlace
# ['Den Haag', 'Amsterdam', 'Haarlem', 'Amsterdam', 'Amsterdam', 'Amsterdam', 'München', 'Amsterdam', 'Haarlem', 'Parijs']
# num entries 2694 - unique entries 426
# --
# http://purl.org/collections/nl/am/biography
# ['zilversmid, werkzaam 1529-1561', 'beeldhouwer', 'Schepen te Dordrecht; Raad en Schepen te Amsterdam', 'Burgemeester van Amsterdam 1842-1852', 'werkzaam in Amsterdam 1869-na 1938)', 'niet in Thieme Becker', 'regent van het oudezijds huiszitten-aalmoezeniershuis, tevens regent van het weduwenhof; 1806', 'regent van het leprozenhuis 1814-1826', 'huwde 3 maart 1910 Joseph Vintura (1880-?)', 'zilversmid, werkzaam 1855-1858']
# num entries 1953 - unique entries 1683
# --
# http://purl.org/collections/nl/am/exhibitionNotes
# ['Object zelf is tentoonstelling', 'Alleen KB 2337.1 t/m 8 gaan naar de tentoonstelling.', 'showroom', 'Object zelf is tentoonstelling', 'Uitgeleend via het RMA', '-', 'op het kaartje: Egbert Gerbrantsz en zijn vrouw zijn op het schilderij omringd door vergankelijkheidssymbolen, zoals gebruikelijk in portretkunst van de 16e eeuw', 'cat.nr. samen met SA 25978', 'Alleen KA 18069.2 gaat naar de tentoonstelling', 'Object is zelf gelijk aan deze tentoonstelling.']
# num entries 211 - unique entries 96
# --
# http://purl.org/collections/nl/am/AHMTextsAuthor
# ['Vreeken, Bert', 'Vreeken, Bert', 'Rooseboom, Hans', 'Dekker, Annemarie den', 'Blankert, Albert', 'Blankert, Albert', 'Blankert, Albert', 'Vreeken, Bert', 'Jonker, Michiel', 'Middelkoop, Norbert']
# num entries 4407 - unique entries 52
# --
# http://purl.org/collections/nl/am/deathDateEnd
# ['1944', '1821/02/12', '1712', '1776/10/03', '1972-10-08', '1786', '1693', '1816-01-30', '1702', '1843']
# num entries 3074 - unique entries 2040
# --
# http://purl.org/collections/nl/am/relatedObjectNotes
# ['p. 159', "Rechts in het vertrek op 'Drie regententen en de binnenmoeder van het Leprozenhuis' van Louis Moritz is 'De Dam in 1604 tijdens de laatste Leprozenommegang op Koppertjesmaandag' van Adriaen van Nieulandt afgebeeld.", 'p. 214', 'p. 99', 'p. 85', 'p. 148', 'p. 15', 'p. 123', 'p. 166', 'p. 325']
# num entries 1044 - unique entries 421
# --
# http://purl.org/collections/nl/am/creditLine
# ['Amsterdams Historisch Museum, legaat C.J. Fodor', 'Amsterdams Historisch Museum, schenking kinderen C.P. van Eeghen', 'Amsterdams Historisch Museum, bruikleen van Stichting Spirit', 'Amsterdams Historisch Museum, schenking kinderen C.P. van Eeghen', 'Amsterdams Historisch Museum, bruikleen van Stichting Spirit', 'Amsterdams Historisch Museum, schenking kinderen C.P. van Eeghen', 'Amsterdams Historisch Museum, legaat C.J. Fodor', 'Amsterdams Historisch Museum, legaat C.J. Fodor', 'Amsterdams Historisch Museum, bruikleen Rijksmuseum Amsterdam', 'Amsterdams Historisch Museum, bruikleen van Stichting Spirit']
# num entries 6954 - unique entries 176
# --
# http://purl.org/collections/nl/am/exhibitionCatalogueNumber
# ['343', '39', 'nr. 30', '10', '221', '421', 'AHM', '35', '3', '851']
# num entries 802 - unique entries 412
# --
# http://purl.org/collections/nl/am/relatedObjectTitle
# ['Veren waaier, in doos (doos)', 'Reclameletters firma T.M. Mendelson (letter E)', 'franje', 'Waaiersteun', 'Maatstok', 'Gevelplaat met naam firma T.M. Mendelson in doos (doos)', 'band', 'stempels met stempeldoos Fa. T.M. Mendelson', 'Waaiersteun', 'lappen met gitten']
# num entries 1761 - unique entries 68
# --
# http://www.w3.org/2004/02/skos/core#altLabel
# ['beursgebouwen', 'boekwinkel', 'Barbizon, School van', 'dominees', 'epidemieën', 'Paris', 'lijkdichten', 'papierrestauratie', 'huwelijksgedichten', 'historiologie']
# num entries 558 - unique entries 546
# --
# http://purl.org/collections/nl/am/birthDatePrecision
# ['ca', 'ca. 1497', 'ca.', 'circa', '?', 'ca.', 'ca', '1597', '1617', 'waarschijnlijk 1633']
# num entries 286 - unique entries 167
# --
# http://purl.org/collections/nl/am/value
# ['motief', 'Spitzenbegriff', 'COLL', 'CATEGORY', 'ROLE', 'LOANCAT', 'acquisition', 'activity', 'CONCEPT', 'materiaal']
# num entries 202 - unique entries 197
# --
# http://purl.org/collections/nl/am/occupation
# ['schilder', 'droogscheerder', '1539-41 burgemeester', 'goud- en zilversmid', 'beeldhouwer', 'diaconesse', 'drukker', 'tentoonstellingsmaker/curator', 'notaris', 'koopman']
# num entries 786 - unique entries 245
# --
# http://purl.org/collections/nl/am/AHMTextsReference
# ['..\\..\\DAT\\Collectie\\objectteksten\\KB_871_KB_872.pdf', '..\\..\\DAT\\collectie\\objectteksten\\SB 5812 zaaltekst.doc', '..\\..\\DAT\\collectie\\objectteksten\\KA_3686_1_37_KA_18444_1_2_KA_18086.pdf', '..\\..\\DAT\\collectie\\objectdocumentatie\\glas 1998\\collectie\\KA_18249\\index.html', '..\\..\\DAT\\Collectie\\objectteksten\\SB_6374_SB_6383.pdf', '..\\..\\DAT\\Collectie\\objectteksten\\KB_3768_KB_3769_KB_3770_KB_3771_KB_3772_KB_3773.pdf', '..\\..\\DAT\\collectie\\objectdocumentatie\\glas 1998\\collectie\\KA_5312\\index.html', '..\\..\\DAT\\Collectie\\objectteksten\\KB_768.pdf', '..\\..\\DAT\\collectie\\objectdocumentatie\\glas 1998\\collectie\\KA_15356\\index.html', '..\\..\\DAT\\collectie\\objectteksten\\KA_3686_1_37_KA_18444_1_2_KA_18086.pdf']
# num entries 2088 - unique entries 856
# --
# http://purl.org/collections/nl/am/exhibitionVenue
# ['The J. Paul Getty Museum', 'Waag, de', 'Historisch Museum', 'Princessehof', "Cabinet des Estampes, Museé d'Art en d'Histoire", 'Princessehof', 'Franckesche Stiftungen', 'Stichting Projecten De Nieuwe Kerk  Amsterdam', 'Stichting Stedelijk Museum Amsterdam', 'Universiteitsbibliotheek  (Amsterdam)']
# num entries 1514 - unique entries 247
# --
# http://purl.org/collections/nl/am/deathDateStart
# ['1625', '1941', '1675 (na)', '1987-06-21', '1879-10-10', '1604', '1916', '1824-02-24', '1661', '1860']
# num entries 4887 - unique entries 2187
# --
# http://purl.org/collections/nl/am/ownershipHistoryFreeText
# ['Legaat A. van der Hoop, 1854; bruikleen aan Rijksmuseum, 1885', 'De pakje behoorde tot een schenking van 17.2.1978 aan het Nederlands Kostuum Museum in Den Haag door Mevr. J.A: Zeldenrust-De Beaufort, Frankrijk en was afkomstig uit de nalatenschap van haar moeder Mevr. De Beaufort, wonende op het huis “De Treek” te Leusden.', 'Bruikleen Spirit, 1962; schoorsteenstuk Regentenkamer Burgerweeshuis, thans onderdeel van het AHM', "Veiling Van der Zande 1855, p. 346, nr. 3032: 'Ostade (Adrien Van). Cinq paysans assis à boire et à fumer. Une femme leur apporte un pot de bière ; à gauche, un chien couché. Morceau d'une admirable exécution, à plume et lavé d'encre de Chine. On y a joint l'eau-fort qu'en a gravée, en plus petit, F. Hillemacher' (fr. 1.700,-) ; Veiling Norblin 1860, p. 18, nr. 111 \nOstade (Adrien Van). Cinq paysans assis à boire et à fumer. Une femme leur apporte un pot de bière ; à gauche, un chien couché. Morceau d'une admirable exécution, à plume et lavé d'encre de Chine. On y a joint l'eau-fort qu'en a gravée, en plus petit, F. Hillemacher. Ce beau dessin provient de la collection Van den Zande. La description que nous en donnons est extraite du catalogue rédigé par M. Guichardot' (fr. 3020,- , aan C.J. Fodor) ; Collectie C.J. Fodor, legaat 1860", 'Verzameling Christina Catharina Kemper-de Vries, Leiden, waarschijnlijk ná 1824; van Christina Catharina Kemper-de Vries, gekocht door Adriaan van der Hoop door bemiddeling van haar broer, kunsthandelaar Jeronimo de Vries, 1833; legaat aan de Stad Amsterdam, 1854; Museum Van der Hoop, 1854-1885; bruikleen aan Rijksmuseum, 1885', 'Aankoop 1936, van  Kunsthandel E. Speelman, Londen, (Fl. 60,-), (volgens documentatiearchief), vermeld in het jaarverslag over dat jaar, p. 16', 'Diaconie Oude Vrouwenhuis, Amsterdam; geschenk van de Diaconie der Hervormde Gemeente, Amsterdam, 1994', 'Verzameling W.J.R. Dreesmann, Amsterdam; veiling Frederik Muller 22/25-3-1960, nr. 152', 'Het kostuum is gedragen door J.H. Scheltema, van 1904-1921 gemeenteraadslid van Amsterdam voor de Bond van Vrije Liberalen, hij was tevens lid van de Amsterdamsche Eerewacht. Het kostuum is geschonken door zijn jongste zoon, Mr. C. Scheltema. (schr. mw. E.A.M. Scheltema-Vriesendorp, 1983/12/16)', 'Veiling Marie-Caroline de Bourbon, Duchesse de Berry (Parijs), Londen (Christie’s), april 1834, nr. 101, niet verkocht; veiling Marie-Caroline de Bourbon, Duchesse de Berry, Parijs, 4 april 1837, nr. 87, aan kunsthandelaar H,ris voor Adriaan van der Hoop door bemiddeling van de kunsthandelaar Albertus Brondgeest; legaat aan de Stad Amsterdam, 1854; Museum Van der Hoop, 1854-1885; bruikleen aan Rijksmuseum, 1885']
# num entries 3412 - unique entries 1749
# --
# http://purl.org/collections/nl/am/source
# ['AHM', 'AAT', 'AHM', 'AHM', 'AAT zonder hierarchie', 'niet in AAT', 'AHM', 'niet in AAT', 'AAT', 'AAT']
# num entries 1096 - unique entries 34
# --
# http://purl.org/collections/nl/am/equivalentName
# ['Internationaal Instituut voor Sociale Geschiedenis', 'V.V.H.K.', 'Bouts, Dirk', 'Eijl, dhr. G.G.L.F.Th. van', 'Sotheby Mak van Waay B.V.', 'Voltaire', 'Verster, Floris', 'Wolf, N.H.', 'Linde, Hans van der', 'Protestantse Diaconie Amsterdam']
# num entries 1015 - unique entries 764
# --
# http://purl.org/collections/nl/am/use
# ['Amsterdamsch Studenten Corps', 'Grégoire, Jan', 'Groen, Marga', 'Kunstgezelschap M.A.B.', 'Iliohan, Mevrouw J.', 'Stichting Hulp na Onderzoek', 'A. Boersma', "Sa'di, Mušarrif al-Din b. Muslih", 'O+S', 'Bezige Bij, De']
# num entries 1855 - unique entries 1425
# --
# http://purl.org/collections/nl/am/scopeNote
# ['Drinkgerei gemaakt van een hoorn, in zilver of brons gemonteerd.', 'Kleine vijlen die van metaal of karton zijn gemaakt en worden gebruikt voor het bijwerken, gladmaken en scherp maken van vingernagels. Hebben soms een punt om het vuil onder de nagels te verwijderen.', '(bron: GAA)', '(bron: GAA)', '(bron: GAA)', '(bron: GAA)', 'decoratieve kunststijl van de Renaissance-barok (AAT-NL)', 'bewerkte huid van kalf, schaap, geit enz. geschikt om erop te schrijven, boeken in te binden of als trommelvel', 'Objecten dan wel voorgevormde of buigzame bedekkingen, bedoeld om voorwerpen of stoffen te bevatten, te bewaren of te verschepen.', '(bron: GAA)']
# num entries 726 - unique entries 540
# --
# http://purl.org/collections/nl/am/creator
# ['Stereo beschuit- en koekfabriek N. V. Rotterdam', 'J. F. Jarvis', 'Underwood & Underwood', 'Underwood & Underwood', 'Underwood & Underwood', 'Underwood & Underwood', 'J. F. Jarvis', 'Underwood & Underwood', 'Jarvis, J. F.', 'Underwood & Underwood']
# num entries 226 - unique entries 23
# --
# http://purl.org/collections/nl/am/deathDatePrecision
# ['na 1729', 'ca.', 'na 1690', 'vermoedelijk 1807', 'vóór', '05-31', '1951-11-02', "1626-'27", '1840-06-19', '12-29']
# num entries 185 - unique entries 131
# --
# http://purl.org/collections/nl/am/birthNotes
# ['Ca. 1625', 'Gedoopt: 1734/07/18', 'doop', '1690 (?)', 'Gedoopt: 1720/11/13', 'ca. 1815', 'Ca. 1565', 'volgens Willigen 1643/44', 'Gedoopt op 14 december 1806', 'Gedoopt: 1666/12/21']
# num entries 455 - unique entries 408
# --
# http://purl.org/collections/nl/am/exhibitionObjectLocation
# ['V. m', 'kast', '9V2M/06', 'kast', 'V.h', '9V2M/04', 'V. x', 'V. x', '06VR/04', '06VR/08']
# num entries 250 - unique entries 154
# --
# http://purl.org/collections/nl/am/exhibitionCode
# ['1.3', '1.4', '6.1.3', '6.2.3', '1.3', '1.6', '3.2.3', '6.1.3', '1.3', '1.3']
# num entries 295 - unique entries 40
# --
# http://purl.org/collections/nl/am/documentationAuthor
# ['Schipper, Daniël', 'Lavèn, Annemarie', 'Schipper, Daniël', 'Lavèn, Annemarie', 'Schipper, Daniël', 'Dehé, John', 'Schipper, Daniël', 'Schipper, Daniël', 'Lavèn, Annemarie', 'Schoots, Hans']
# num entries 22 - unique entries 5
# --
# http://purl.org/collections/nl/am/deathNotes
# ['(ca.)', 'ca. 1611', 'Bij Wurzbach: 1652/06/26', 'Gedoopt: 1764/06/13', 'Geboren: 1750/03/16 (Scheen/Thieme-Becker)', 'Gedoopt: 1595/04/06', 'op.c.1850', 'ca.', '1583', 'Ca. 1737']
# num entries 408 - unique entries 363
# --
# http://purl.org/collections/nl/am/alternativeNumberDate
# ['2003-11-06', '2005-09-28', '2003-11-06', '2007', '1995', '1993', '2007', '2004-04', '2003-11-06', '1975']
# num entries 578 - unique entries 74
# --
# http://purl.org/collections/nl/am/currentLocation
# ['AHM dep 3 kast 20-5', 'WH Ontmoet de Willets', 'AHM dep 3 kast 20-5', 'AHM dep 3 kast 20-5', 'Bijkerk, A.Th.', 'AHM dep 3 kast 20-5', 'WH Ontmoet de Willets', 'WH - W10 d', 'AHM dep 3 kast 20-5', 'WH Ontmoet de Willets']
# num entries 382 - unique entries 36
# --
# http://purl.org/collections/nl/am/reproductionNotes
# ['Opmerking Alice de Keijser, d.d. 2008-04-09: crinoline wordt hier "binnenste buiten en achterste voren" getoond. Foto dus niet gebruiken voor publicatie!', 'reproductie toegevoegd door adapl: jweemhoff (2003-04-24)', 'Stempel op achterzijde', '(E22)', 'voorzijde', 'reproductie toegevoegd door adapl: jweemhoff (2003-04-24)', 'Stempel op achterzijde', 'na restauratie 1970-72', 'detail', 'detail']
# num entries 134 - unique entries 38
# --
# http://purl.org/collections/nl/am/relatedObjectAssociation
# ['pendant', 'onderdeel', 'pendant', 'pendant', 'pendant', 'pendant', 'pendant', 'pendant', 'pendant', 'pendant']
# num entries 113 - unique entries 6
# --
# http://purl.org/collections/nl/am/nationality
# ['Nederlandse', 'Nederlandse', 'Duitse', 'Nederlandse', 'Nederlandse', 'Nederlandse', 'Nederlandse', 'Nederlandse', 'Nederlandse', 'Duitse']
# num entries 239 - unique entries 33
# --
# http://purl.org/collections/nl/am/objectName
# ['stereokaart', 'stereokaart', 'stereokaart', 'stereokaart', 'kleinwerk', 'stereokaart', 'stereokaart', 'stereokaart', 'stereokaart', 'stereokaart']
# num entries 418 - unique entries 5
# --
# http://purl.org/collections/nl/am/partsTitle
# ['diverse fournituren, strook imitatie persianer', 'placemat Schreierstoren', 'placemat Schreierstoren', 'diverse fournituren, sierband', 'placemat met hoekhuis trapgevel', 'placemat Koepelkerk', 'Reclameletters firma T.M. Mendelson (letter L)', 'Bril met opzetstukken in doos (doos)', 'vingerdoekje met hoekhuis trapgevel', 'vingerdoekje met hoekhuis trapgevel']
# num entries 68 - unique entries 32
# --
# http://purl.org/collections/nl/am/relatedObjectReference
# ['Ka 13601', 'PB 944', 'TA 15893', 'A 18857 X', '03.06.19.003', 'PB 944', '03.06.22.006.1/2', 'PB 945a', 'KA 6758', 'PB 945a']
# num entries 220 - unique entries 113
# --
# http://purl.org/collections/nl/am/associationSubject
# ['Grand Canyon', 'Martinique', 'Niagara watervallen', 'Thun', 'Brooklyn Bridge', 'Minnesota', 'Cascade du Dard', 'Droogbak', 'Galta tempel', 'Chamonix']
# num entries 166 - unique entries 132
# --
# http://purl.org/collections/nl/am/contentMotifGeneral
# ['groep personen', 'groep personen', 'groep personen', 'groep personen', 'groep personen', 'groep personen', 'groep personen', 'groep personen', 'groep personen', 'groep personen']
# num entries 38 - unique entries 3
# --
# http://purl.org/collections/nl/am/partsReference
# ['KA 2901', 'KB 2633.1/2', 'KB 2135.2', 'KA 19764.71', 'KA 20653.79', 'KA 2897', 'KA 20653.114', 'KA 7203', 'KA 20653.90', 'KA 5975']
# num entries 11 - unique entries 11
# --
# http://purl.org/collections/nl/am/contentSubject
# ['lelie', 'vulkaanuitbarsting', 'Haarlemmerweg 485', 'japonse rok', 'vulkaanuitbarsting', 'Niagara watervallen', 'japonse rok', 'Korsjespoortsteeg 23', 'Buitenkant', 'japonse rok']
# num entries 43 - unique entries 21
# --
# http://purl.org/collections/nl/am/partOfReference
# ['KA 1519, KA 1521', 'KA 1519, KA 1521', 'KB 1727.1/4', 'KA 1519, KA 1521', 'KB 1727.1/4', 'KA 1519, KA 1521', 'KA 1519, KA 1521', 'KB 1727.1/4', 'KA 1519, KA 1521', 'KA 1519, KA 1521']
# num entries 19 - unique entries 3
# --
# http://purl.org/collections/nl/am/associationPerson
# ['Marriott Hotel', 'Patria biscuitfabriek', 'Koopmans, Hyke', 'Faith71', 'Paulowna, Anna', 'Bitterswijk, Marje', 'J. Nooitgedagt', 'S. S. Mosel', 'Aëgerter, Laurence', 'Redlight Fashion Amsterdam']
# num entries 55 - unique entries 35
# --
# http://purl.org/collections/nl/am/technique
# ['geplastificeerd', 'geplastificeerd', 'geplastificeerd', 'geplastificeerd', 'geplastificeerd', 'tamboureren', 'geplastificeerd', 'geplastificeerd', 'geplastificeerd', 'geplastificeerd']
# num entries 18 - unique entries 2
# --
# http://www.w3.org/1999/02/22-rdf-syntax-ns#value
# ['\n      ', '\t', '\n      ', '\t', '\n      ', '\t']
# num entries 6 - unique entries 2
# --
# http://purl.org/collections/nl/am/contentPersonName
# ['Lutherse kerk', 'Kasteel Heidelberg', 'Edinburgh Castle', 'Jenner, Edward', 'Witte Huis', 'Fontein, Dieuwke', 'Witte Huis', 'Paulowna, Anna', 'Bank of England', 'Paulowna, Anna']
# num entries 15 - unique entries 12
# --
# http://purl.org/collections/nl/am/reproductionCreator
# ['Tuijl, Karin van', 'Boom, Eric van den (medailleur)', 'Aëgerter, Laurence', 'Aëgerter, Laurence', 'Aëgerter, Laurence', 'Aëgerter, Laurence', 'Eichelsheim, Leon', 'Eichelsheim, Leon']
# num entries 8 - unique entries 4
# --
# http://purl.org/dc/terms/title
# ['Amsterdam Museum low precision vocabulary alignments', 'Amsterdam Museum (vocabularies)', 'Amsterdam Museum (people database)', 'Amsterdam Museum (metadata)', 'Amsterdam Museum vocabulary alignments', 'Amsterdam Museum', 'Amsterdam Museum (thesaurus)', 'Amsterdam Museum mid precision vocabulary alignments', 'Amsterdam Museum high precision vocabulary alignments']
# num entries 9 - unique entries 9
# --
# http://purl.org/collections/nl/am/productionPlace
# ['Venice, CA']
# num entries 1 - unique entries 1
# --
# http://purl.org/collections/nl/am/exhibitionOrganiser
# ['Palais Fesch', 'Geelvinck Hinlopenhuis', 'Palais Fesch', 'Historisch Museum Het Palthe-Huis, Stichting']
# num entries 4 - unique entries 3
# --
# http://purl.org/collections/nl/am/productionPeriod
# ['1903']
# num entries 1 - unique entries 1
# --
# http://purl.org/collections/nl/am/documentationNotes
# ['ref.']
# num entries 1 - unique entries 1
# --
# http://purl.org/collections/nl/am/dimensionType
# ['diepte uitgeklapt', 'hoogte uitgeklapt']
# num entries 2 - unique entries 2
# --
# http://purl.org/collections/nl/am/lang
# ['neutral']
# num entries 1 - unique entries 1
# --

# %%
# Divide literals in: 
# categoricals: will be modelled as if they are regular nodes
# numericals: will be modelled as univariate numbers
# dates: will be modelled as dates
# strings: will be modelled as textual strings
# all other literal types will be removed!
am = rdflib.Namespace("http://purl.org/collections/nl/am/")
categoricals = [
    am["dimensionPart"],
    am["dimensionUnit"],
    am["currentLocationLref"],
    am["currentLocationType"],
    am["priref"],
    am["AHMTextsAuthorLref"],
    am["exhibitionLref"],
    am["alternativeNumberType"],
    am["documentationShelfmark"],
    am["documentationTitleLref"],
    am["documentationTitleArticle"],
    am["alternativeNumberInstitution"],
    am["exhibitionVenue"],
    am["relatedObjectAssociation"]
]
numericals = [am["dimensionValue"]]
dates = [
    am["reproductionDate"],
    am["currentLocationDateStart"],
    am["documentationSortyear"],
    am["productionDateStart"],
    am["exhibitionDateEnd"],
    am["productionDateEnd"],
    am["currentLocationDateEnd"],
    am["AHMTextsPubl"],
    am["acquisitionDate"],
    am["AHMTextsDate"],
    am["birthDateEnd"],
    am["exhibitionDateStart"],
    am["deathDateEnd"],
    am["deathDateStart"],
]
strings = [
    am["creatorRole"],
    am["name"],
    am["documentationTitle"],
    am["title"],
    rdflib.URIRef("http://www.w3.org/2004/02/skos/core#prefLabel"),
    am["AHMTextsType"],
    am["exhibitionTitle"],
    am["usedFor"],
    am["birthPlace"],
    am["currentLocationFitness"],
    am["creatorQualifier"],
    am["deathPlace"],
    am["AHMTextsTekst"],
    am["biography"],
    am["relatedObjectNotes"],
    am["creditLine"],
    am["relatedObjectTitle"],
    rdflib.URIRef("http://www.w3.org/2004/02/skos/core#altLabel"),
    am["occupation"],
    am["source"],
    am["equivalentName"],
    am["nationality"],
]

# %%
# Store literal types remove literals unaccounted for in previous step
types_to_remove = set(data.node_features.keys()).difference(
    set(strings).union(set(categoricals)).union(set(dates)).union(set(categoricals))
)
removed_literal_idxs = []
for t in types_to_remove:
    removed_literal_idxs.append(torch.tensor(data.node_features[t][0], dtype=torch.long))

# %%
processed_node_features = {}

# %%
def date_to_number(date: str):
    if date is None:
        return None

    date = date.replace("?", "").strip()
    date = date.replace("(", "").strip()
    date = date.replace(")", "").strip()
    date = re.sub(r"(\D*)$", "", date).strip()
    date = re.sub(r"^(\D*)", "", date).strip()

    date = date.replace("/", "-")
    date = date.replace("\\", "-")
    date = date.replace(".", "-")
    date = date.replace(" ", "-")

    if "-" in date:
        parts = date.split("-")
    else:
        parts = [date]

    parts = [p for p in parts if len(p.strip())]
    values = [1, 1 / 12, 1 / 365]
    val = 0
    for v, p in zip(values, parts):
        try:
            val += v * int(p)
        except:
            return torch.nan
    return val


for l in dates:
    indices = torch.tensor(data.node_features[l][0], dtype=torch.long)
    float_dates = torch.tensor(
        [date_to_number(d) for d in data.node_features[l][1]], dtype=torch.float32
    )

    # remove invalid nodes from graph
    removed_literal_idxs.append(indices[torch.isnan(float_dates)])

    indices = indices[~torch.isnan(float_dates)]
    float_dates = float_dates[~torch.isnan(float_dates)]

    processed_node_features[len(processed_node_features)] = [
        indices,
        float_dates.reshape(-1, 1),
    ]

# %%
for l in numericals:
    processed_numericals = []
    for n in data.node_features[l][1]:
        try:
            processed_numericals.append(float(n.replace(",", ".")))
        except:
            processed_numericals.append(torch.nan)

    indices = torch.tensor(data.node_features[l][0], dtype=torch.long)
    numerical_features = torch.tensor(processed_numericals, dtype=torch.float32)


    # remove invalid nodes from graph
    removed_literal_idxs.append(indices[torch.isnan(numerical_features)])

    indices = indices[~torch.isnan(numerical_features)]
    numerical_features = numerical_features[~torch.isnan(numerical_features)]

    processed_node_features[len(processed_node_features)] = [
        indices,
        numerical_features.reshape(-1, 1),
    ]

# %%
tokenizer = AutoTokenizer.from_pretrained("GroNLP/bert-base-dutch-cased")
model = AutoModelForMaskedLM.from_pretrained("GroNLP/bert-base-dutch-cased",)
model = model.to(device)

def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[
        0
    ]  # First element of model_output contains all token embeddings
    input_mask_expanded = (
        attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    )
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask


batch_size = 64
for l in tqdm(strings):
    model.eval()
    indices = torch.tensor(data.node_features[l][0], dtype=torch.long)

    sents = data.node_features[l][1]
    num_batches = math.ceil(len(sents) / batch_size)

    s_embs = []
    for b in range(num_batches):
        inputs = tokenizer(
            sents[b * batch_size : (b + 1) * batch_size],
            padding="max_length",
            return_tensors="pt",
            max_length=256,
            truncation=True
        ).to(device)
        s_emb = mean_pooling(
            model._modules["bert"](
                **inputs
            ),
            inputs["attention_mask"]
        ).detach().cpu()
        s_embs.append(s_emb)

    s_emb = torch.vstack(s_embs)
    
    processed_node_features[len(processed_node_features)] = [
        indices,
        s_emb,
    ]
# Out:
# 100%|██████████| 22/22 [22:21<00:00, 60.99s/it]

# %%
literals = torch.hstack(removed_literal_idxs).squeeze().to(device)
mask = torch.isin(data.edge_index[0], literals) | torch.isin(
    data.edge_index[1], literals
)
edge_index = data.edge_index[:, ~mask]
edge_type = data.edge_type[~mask]

# %%
train_idx, val_idx, y_train, y_val = train_test_split(
    data.train_idx,
    data.train_y,
    stratify=data.train_y.cpu().numpy(),
    test_size=0.1,
    random_state=42,
)

# %%
embedder = RRGCNEmbedder(
    num_nodes=data.num_nodes,
    num_relations=dataset.num_relations,
    num_layers=5,
    emb_size=512,
    device=device,
)

# %%
# for node features to work well, they have to be normalized
# you can choose "standard" for StandardScaler, "robust" for RobustScaler, "quantile"
# for QuantileTransformer and "power" for PowerTransformer
#
# you could also pass sklearn compatible scalers by passing a dict keyed by
# literal type, e.g.:
# {0: StandardScaler(), 1: RobustScaler()}
from sklearn.preprocessing import StandardScaler, QuantileTransformer

train_embs = embedder.embeddings(
    edge_index,
    edge_type,
    node_features=processed_node_features,
    node_features_scalers={
        k: None
        if v[1].shape[1] > 1
        else QuantileTransformer(output_distribution="normal")
        for k, v in processed_node_features.items()
    },
    idx=train_idx,
)
# Out:
# 100%|██████████| 1/1 [03:00<00:00, 180.20s/it]

# %%
# only fit node feature scalers on nodes reachable from train nodes,
# for val and test nodes, reuse the fit scalers using embedder.get_last_fit_scalers()
val_embs = embedder.embeddings(
    edge_index,
    edge_type,
    node_features=processed_node_features,
    node_features_scalers=embedder.get_last_fit_scalers(),
    idx=val_idx,
)
test_embs = embedder.embeddings(
    edge_index,
    edge_type,
    node_features=processed_node_features,
    node_features_scalers=embedder.get_last_fit_scalers(),
    idx=data.test_idx,
)
# Out:
# 100%|██████████| 1/1 [03:01<00:00, 181.36s/it]
# 100%|██████████| 1/1 [03:04<00:00, 184.37s/it]

# %%
task_type = "GPU" if torch.cuda.is_available() else "CPU"
clf = CatBoostClassifier(
    iterations=10_000,
    learning_rate=0.10,
    early_stopping_rounds=100,
    task_type=task_type,
    random_seed=42,
    use_best_model=True,
    auto_class_weights="Balanced",
    verbose=False
)
clf = clf.fit(
    train_embs.cpu().numpy(),
    y_train.cpu().numpy(),
    eval_set=(val_embs.cpu().numpy(), y_val.cpu().numpy()),
)
# Out:
# Warning: less than 75% gpu memory available for training. Free: 8260.25 Total: 32510.5

# %%
print(classification_report(data.test_y.cpu().numpy(), clf.predict(test_embs.cpu().numpy())))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88         8
#            1       0.97      1.00      0.99        69
#            2       1.00      0.80      0.89         5
#            3       0.93      0.81      0.87        16
#            4       0.89      0.73      0.80        11
#            5       1.00      1.00      1.00        11
#            6       1.00      1.00      1.00         3
#            7       0.70      1.00      0.82        23
#            8       0.94      0.88      0.91        17
#            9       0.83      0.60      0.70        25
#           10       0.55      0.60      0.57        10
#
#     accuracy                           0.88       198
#    macro avg       0.88      0.85      0.86       198
# weighted avg       0.89      0.88      0.88       198
